# %%
#Load dependencies
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
#Load csvs for each dataset
cab_data_path = "Data/Cab_Data.csv"
cab_data = pd.read_csv(cab_data_path)

# %%
cab_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011       1/8/2016    Pink Cab     ATLANTA GA
# 1             10000012       1/6/2016    Pink Cab     ATLANTA GA
# 2             10000013       1/2/2016    Pink Cab     ATLANTA GA
# 3             10000014       1/7/2016    Pink Cab     ATLANTA GA
# 4             10000015       1/3/2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101       1/8/2018  Yellow Cab  WASHINGTON DC
# 359388        10440104       1/4/2018  Yellow Cab  WASHINGTON DC
# 359389        10440105       1/5/2018  Yellow Cab  WASHINGTON DC
# 359390        10440106       1/5/2018  Yellow Cab  WASHINGTON DC
# 359391        10440107       1/2/2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192
#
# [359392 rows x 7 columns]

# %%
city_data_path = "Data/City.csv"
city_data = pd.read_csv(city_data_path)

# %%
city_data
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
cstmr_data_path = "Data/Customer_ID.csv"
customer_data = pd.read_csv(cstmr_data_path)

# %%
customer_data
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
trans_data_path = "Data/Transaction_ID.csv"
trans_data = pd.read_csv(trans_data_path)

# %%
trans_data
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
#merge customer_data and trans_data (transaction data) on Customer ID

combined_data = pd.merge(customer_data, trans_data, how='left')

# %%
combined_data
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...             ...
# 440093         Cash
# 440094         Card
# 440095         Card
# 440096         Cash
# 440097         Card
#
# [440098 rows x 6 columns]

# %%
#merge combined customer and transaction data with cab_data on Transaction ID
master_data = pd.merge(cab_data, combined_data, how="left")

# %%
master_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011       1/8/2016    Pink Cab     ATLANTA GA
# 1             10000012       1/6/2016    Pink Cab     ATLANTA GA
# 2             10000013       1/2/2016    Pink Cab     ATLANTA GA
# 3             10000014       1/7/2016    Pink Cab     ATLANTA GA
# 4             10000015       1/3/2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101       1/8/2018  Yellow Cab  WASHINGTON DC
# 359388        10440104       1/4/2018  Yellow Cab  WASHINGTON DC
# 359389        10440105       1/5/2018  Yellow Cab  WASHINGTON DC
# 359390        10440106       1/5/2018  Yellow Cab  WASHINGTON DC
# 359391        10440107       1/2/2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# 1              28.62         358.52      334.8540        27703   Male   27
# 2               9.04         125.20       97.6320        28712   Male   53
# 3              33.17         377.40      351.6020        28020   Male   23
# 4               8.73         114.62       97.7760        27182   Male   33
# ...              ...            ...           ...          ...    ...  ...
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode
# 0                    10813         Card
# 1                     9237         Card
# 2                    11242         Cash
# 3                    23327         Cash
# 4                     8536         Card
# ...                    ...          ...
# 359387               15651         Cash
# 359388                6528         Cash
# 359389                7966         Cash
# 359390                6423         Card
# 359391               11284         Card
#
# [359392 rows x 12 columns]

# %%
#total rides by company
pink_data = pd.DataFrame(columns=['Date of Travel','Company', 'City', 'Customer ID', 'Gender', 'Age', 'Income (USD/Month)',
                         'KM Travelled','Cost of Trip', 'Price Charged', 'Trip Profit','Payment_Mode'])

# %%
#profit
master_data['Trip Profit'] = master_data['Price Charged']-master_data['Cost of Trip']

# %%
master_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011       1/8/2016    Pink Cab     ATLANTA GA
# 1             10000012       1/6/2016    Pink Cab     ATLANTA GA
# 2             10000013       1/2/2016    Pink Cab     ATLANTA GA
# 3             10000014       1/7/2016    Pink Cab     ATLANTA GA
# 4             10000015       1/3/2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101       1/8/2018  Yellow Cab  WASHINGTON DC
# 359388        10440104       1/4/2018  Yellow Cab  WASHINGTON DC
# 359389        10440105       1/5/2018  Yellow Cab  WASHINGTON DC
# 359390        10440106       1/5/2018  Yellow Cab  WASHINGTON DC
# 359391        10440107       1/2/2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# 1              28.62         358.52      334.8540        27703   Male   27
# 2               9.04         125.20       97.6320        28712   Male   53
# 3              33.17         377.40      351.6020        28020   Male   23
# 4               8.73         114.62       97.7760        27182   Male   33
# ...              ...            ...           ...          ...    ...  ...
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode  Trip Profit
# 0                    10813         Card      57.3150
# 1                     9237         Card      23.6660
# 2                    11242         Cash      27.5680
# 3                    23327         Cash      25.7980
# 4                     8536         Card      16.8440
# ...                    ...          ...          ...
# 359387               15651         Cash       5.8800
# 359388                6528         Cash       6.9020
# 359389                7966         Cash      87.4200
# 359390                6423         Card      32.1420
# 359391               11284         Card      13.9608
#
# [359392 rows x 13 columns]

# %%
master_data = master_data[['Date of Travel','Company', 'City', 'Customer ID', 'Gender', 'Age', 'Income (USD/Month)',
                         'KM Travelled','Cost of Trip', 'Price Charged', 'Trip Profit','Payment_Mode']]

# %%
master_data
# Out:
#        Date of Travel     Company           City  Customer ID Gender  Age  \
# 0            1/8/2016    Pink Cab     ATLANTA GA        29290   Male   28
# 1            1/6/2016    Pink Cab     ATLANTA GA        27703   Male   27
# 2            1/2/2016    Pink Cab     ATLANTA GA        28712   Male   53
# 3            1/7/2016    Pink Cab     ATLANTA GA        28020   Male   23
# 4            1/3/2016    Pink Cab     ATLANTA GA        27182   Male   33
# ...               ...         ...            ...          ...    ...  ...
# 359387       1/8/2018  Yellow Cab  WASHINGTON DC        52392   Male   24
# 359388       1/4/2018  Yellow Cab  WASHINGTON DC        53286   Male   32
# 359389       1/5/2018  Yellow Cab  WASHINGTON DC        52265   Male   56
# 359390       1/5/2018  Yellow Cab  WASHINGTON DC        52175   Male   32
# 359391       1/2/2018  Yellow Cab  WASHINGTON DC        52917   Male   20
#
#         Income (USD/Month)  KM Travelled  Cost of Trip  Price Charged  \
# 0                    10813         30.45      313.6350         370.95
# 1                     9237         28.62      334.8540         358.52
# 2                    11242          9.04       97.6320         125.20
# 3                    23327         33.17      351.6020         377.40
# 4                     8536          8.73       97.7760         114.62
# ...                    ...           ...           ...            ...
# 359387               15651          4.80       63.3600          69.24
# 359388                6528          8.40      106.8480         113.75
# 359389                7966         27.75      349.6500         437.07
# 359390                6423          8.80      114.0480         146.19
# 359391               11284         12.76      177.6192         191.58
#
#         Trip Profit Payment_Mode
# 0           57.3150         Card
# 1           23.6660         Card
# 2           27.5680         Cash
# 3           25.7980         Cash
# 4           16.8440         Card
# ...             ...          ...
# 359387       5.8800         Cash
# 359388       6.9020         Cash
# 359389      87.4200         Cash
# 359390      32.1420         Card
# 359391      13.9608         Card
#
# [359392 rows x 12 columns]

# %%
#price per KM
master_data['Price Per KM']=master_data['Cost of Trip']/master_data['KM Travelled']

# %%
master_data = master_data[['Date of Travel','Company', 'City', 'Customer ID', 'Gender', 'Age', 'Income (USD/Month)',
                         'KM Travelled','Cost of Trip', 'Price Charged', 'Trip Profit','Price Per KM','Payment_Mode']]

# %%
master_data
# Out:
#        Date of Travel     Company           City  Customer ID Gender  Age  \
# 0            1/8/2016    Pink Cab     ATLANTA GA        29290   Male   28
# 1            1/6/2016    Pink Cab     ATLANTA GA        27703   Male   27
# 2            1/2/2016    Pink Cab     ATLANTA GA        28712   Male   53
# 3            1/7/2016    Pink Cab     ATLANTA GA        28020   Male   23
# 4            1/3/2016    Pink Cab     ATLANTA GA        27182   Male   33
# ...               ...         ...            ...          ...    ...  ...
# 359387       1/8/2018  Yellow Cab  WASHINGTON DC        52392   Male   24
# 359388       1/4/2018  Yellow Cab  WASHINGTON DC        53286   Male   32
# 359389       1/5/2018  Yellow Cab  WASHINGTON DC        52265   Male   56
# 359390       1/5/2018  Yellow Cab  WASHINGTON DC        52175   Male   32
# 359391       1/2/2018  Yellow Cab  WASHINGTON DC        52917   Male   20
#
#         Income (USD/Month)  KM Travelled  Cost of Trip  Price Charged  \
# 0                    10813         30.45      313.6350         370.95
# 1                     9237         28.62      334.8540         358.52
# 2                    11242          9.04       97.6320         125.20
# 3                    23327         33.17      351.6020         377.40
# 4                     8536          8.73       97.7760         114.62
# ...                    ...           ...           ...            ...
# 359387               15651          4.80       63.3600          69.24
# 359388                6528          8.40      106.8480         113.75
# 359389                7966         27.75      349.6500         437.07
# 359390                6423          8.80      114.0480         146.19
# 359391               11284         12.76      177.6192         191.58
#
#         Trip Profit  Price Per KM Payment_Mode
# 0           57.3150         10.30         Card
# 1           23.6660         11.70         Card
# 2           27.5680         10.80         Cash
# 3           25.7980         10.60         Cash
# 4           16.8440         11.20         Card
# ...             ...           ...          ...
# 359387       5.8800         13.20         Cash
# 359388       6.9020         12.72         Cash
# 359389      87.4200         12.60         Cash
# 359390      32.1420         12.96         Card
# 359391      13.9608         13.92         Card
#
# [359392 rows x 13 columns]

# %%
#total rides by company
pink_data = pd.DataFrame(columns=['Date of Travel','Company', 'City', 'Customer ID', 'Gender', 'Age', 'Income (USD/Month)',
                         'KM Travelled','Cost of Trip', 'Price Charged', 'Trip Profit','Payment_Mode'])
pink_data = master_data.loc[master_data['Company']=='Pink Cab']
pink_data
# Out:
#        Date of Travel   Company           City  Customer ID  Gender  Age  \
# 0            1/8/2016  Pink Cab     ATLANTA GA        29290    Male   28
# 1            1/6/2016  Pink Cab     ATLANTA GA        27703    Male   27
# 2            1/2/2016  Pink Cab     ATLANTA GA        28712    Male   53
# 3            1/7/2016  Pink Cab     ATLANTA GA        28020    Male   23
# 4            1/3/2016  Pink Cab     ATLANTA GA        27182    Male   33
# ...               ...       ...            ...          ...     ...  ...
# 357449       1/6/2018  Pink Cab  WASHINGTON DC        51142  Female   40
# 357450     12/31/2018  Pink Cab  WASHINGTON DC        52754  Female   29
# 357451       1/7/2018  Pink Cab  WASHINGTON DC        53039    Male   37
# 357452       1/2/2018  Pink Cab  WASHINGTON DC        51766    Male   18
# 357453       1/5/2018  Pink Cab  WASHINGTON DC        51996    Male   36
#
#         Income (USD/Month)  KM Travelled  Cost of Trip  Price Charged  \
# 0                    10813         30.45       313.635         370.95
# 1                     9237         28.62       334.854         358.52
# 2                    11242          9.04        97.632         125.20
# 3                    23327         33.17       351.602         377.40
# 4                     8536          8.73        97.776         114.62
# ...                    ...           ...           ...            ...
# 357449                3122         13.56       135.600         184.19
# 357450               19676         29.68       302.736         388.08
# 357451               22765         28.50       310.650         369.04
# 357452               12364         16.10       162.610         194.17
# 357453               12905         22.20       244.200         287.46
#
#         Trip Profit Payment_Mode
# 0            57.315         Card
# 1            23.666         Card
# 2            27.568         Cash
# 3            25.798         Cash
# 4            16.844         Card
# ...             ...          ...
# 357449       48.590         Card
# 357450       85.344         Card
# 357451       58.390         Card
# 357452       31.560         Cash
# 357453       43.260         Cash
#
# [84711 rows x 12 columns]

# %%
yellow_data = pd.DataFrame(columns=['Date of Travel','Company', 'City', 'Customer ID', 'Gender', 'Age', 'Income (USD/Month)',
                         'KM Travelled','Cost of Trip', 'Price Charged', 'Trip Profit','Payment_Mode'])
yellow_data = master_data.loc[master_data['Company']=='Yellow Cab']
yellow_data
# Out:
#        Date of Travel     Company           City  Customer ID Gender  Age  \
# 233          1/2/2016  Yellow Cab     ATLANTA GA        27602   Male   23
# 234          1/9/2016  Yellow Cab     ATLANTA GA        27594   Male   28
# 235          1/3/2016  Yellow Cab     ATLANTA GA        27884   Male   32
# 236          1/6/2016  Yellow Cab     ATLANTA GA        28533   Male   39
# 237          1/7/2016  Yellow Cab     ATLANTA GA        29039   Male   35
# ...               ...         ...            ...          ...    ...  ...
# 359387       1/8/2018  Yellow Cab  WASHINGTON DC        52392   Male   24
# 359388       1/4/2018  Yellow Cab  WASHINGTON DC        53286   Male   32
# 359389       1/5/2018  Yellow Cab  WASHINGTON DC        52265   Male   56
# 359390       1/5/2018  Yellow Cab  WASHINGTON DC        52175   Male   32
# 359391       1/2/2018  Yellow Cab  WASHINGTON DC        52917   Male   20
#
#         Income (USD/Month)  KM Travelled  Cost of Trip  Price Charged  \
# 233                   8542         33.93      464.1624        1341.17
# 234                   3901         42.18      516.2832        1412.06
# 235                  13505         10.60      132.2880         364.62
# 236                  28386         26.75      333.8400         838.00
# 237                  17761         46.02      596.4192        1540.61
# ...                    ...           ...           ...            ...
# 359387               15651          4.80       63.3600          69.24
# 359388                6528          8.40      106.8480         113.75
# 359389                7966         27.75      349.6500         437.07
# 359390                6423          8.80      114.0480         146.19
# 359391               11284         12.76      177.6192         191.58
#
#         Trip Profit Payment_Mode
# 233        877.0076         Card
# 234        895.7768         Cash
# 235        232.3320         Cash
# 236        504.1600         Cash
# 237        944.1908         Card
# ...             ...          ...
# 359387       5.8800         Cash
# 359388       6.9020         Cash
# 359389      87.4200         Cash
# 359390      32.1420         Card
# 359391      13.9608         Card
#
# [274681 rows x 12 columns]

# %%
#number of repeat rides per customer
ride_freq = master_data.pivot_table(columns='Customer ID','Company'], aggfunc='size')

# %%
ride_freq
# Out:
# Customer ID  Company
# 1            Pink Cab       4
#              Yellow Cab    25
# 2            Pink Cab       4
#              Yellow Cab    36
# 3            Pink Cab       6
#                            ..
# 59998        Yellow Cab     6
# 59999        Pink Cab       2
#              Yellow Cab     6
# 60000        Pink Cab       4
#              Yellow Cab    14
# Length: 72226, dtype: int64

# %%
ride_freq = ride_freq.reset_index()

# %%
ride_freq
# Out:
#        Customer ID     Company   0
# 0                1    Pink Cab   4
# 1                1  Yellow Cab  25
# 2                2    Pink Cab   4
# 3                2  Yellow Cab  36
# 4                3    Pink Cab   6
# ...            ...         ...  ..
# 72221        59998  Yellow Cab   6
# 72222        59999    Pink Cab   2
# 72223        59999  Yellow Cab   6
# 72224        60000    Pink Cab   4
# 72225        60000  Yellow Cab  14
#
# [72226 rows x 3 columns]

# %%
ride_freq.columns = ['Customer ID', 'Company', 'Rides Taken']

# %%
ride_freq
# Out:
#        Customer ID     Company  Rides Taken
# 0                1    Pink Cab            4
# 1                1  Yellow Cab           25
# 2                2    Pink Cab            4
# 3                2  Yellow Cab           36
# 4                3    Pink Cab            6
# ...            ...         ...          ...
# 72221        59998  Yellow Cab            6
# 72222        59999    Pink Cab            2
# 72223        59999  Yellow Cab            6
# 72224        60000    Pink Cab            4
# 72225        60000  Yellow Cab           14
#
# [72226 rows x 3 columns]

# %%
combined_sorted = combined_data.sort_values('Customer ID')

# %%
combined_sorted = combined_sorted.reset_index()

# %%
combined_sorted = combined_sorted.drop('index', axis =1)

# %%
combined_sorted = combined_sorted.drop_duplicates('Customer ID')

# %%
combined_sorted = combined_sorted.reset_index()

# %%
customer_transactions = combined_sorted

# %%
master_data.to_csv(r'Data\master_data.csv')

# %%
pink_data.to_csv(r'Data\pink_cab.csv')

# %%
yellow_data.to_csv(r'Data\yellow_cab.csv')

# %%
customer_transactions.to_csv(r'Data\customer_transactions.csv')
